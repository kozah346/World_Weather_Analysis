# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | kosh-agach
# Processing Record 4 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | durham
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | sulphur springs
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | nabire
# Processing Record 12 of Set 1 | quzhou
# Processing Record 13 of Set 1 | pimentel
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | marsabit
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | aklavik
# Processing Record 18 of Set 1 | port lincoln
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | araouane
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | saint-francois
# Processing Record 24 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 25 of Set 1 | marsh harbour
# Processing Record 26 of Set 1 | kaduna
# Processing Record 27 of Set 1 | iskateley
# Processing Record 28 of Set 1 | bonavista
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | mahibadhoo
# Processing Record 31 of Set 1 | portland
# Processing Record 32 of Set 1 | wattegama
# Processing Record 33 of Set 1 | coahuayana
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | ambilobe
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | hauterive
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | teknaf
# Processing Record 49 of Set 1 | saint-georges
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | cap malheureux
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | sovetskaya gavan
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | carballo
# Processing Record 8 of Set 2 | yellamanchili
# City not found. Skipping...
# Processing Record 9 of Set 2 | touros
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | ust-tsilma
# Processing Record 13 of Set 2 | olkhovatka
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | asfi
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | leningradskiy
# Processing Record 18 of Set 2 | panacan
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | hami
# Processing Record 21 of Set 2 | alofi
# Processing Record 22 of Set 2 | cabedelo
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | benghazi
# Processing Record 25 of Set 2 | khuzhir
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | coquimbo
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | lompoc
# Processing Record 33 of Set 2 | chikoy
# City not found. Skipping...
# Processing Record 34 of Set 2 | geraldton
# Processing Record 35 of Set 2 | kropotkin
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | haines junction
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | naze
# Processing Record 47 of Set 2 | oktyabrskoye
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | havoysund
# Processing Record 50 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 3 | victoria
# Processing Record 2 of Set 3 | laohekou
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | tromso
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | talnakh
# Processing Record 8 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | dubasari
# Processing Record 11 of Set 3 | kasongo-lunda
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | joensuu
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | camacha
# Processing Record 16 of Set 3 | guatire
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | talaya
# Processing Record 19 of Set 3 | veraval
# Processing Record 20 of Set 3 | malakal
# Processing Record 21 of Set 3 | murdochville
# Processing Record 22 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 3 | chato
# Processing Record 24 of Set 3 | mayskiy
# Processing Record 25 of Set 3 | lagoa
# Processing Record 26 of Set 3 | levelland
# Processing Record 27 of Set 3 | shache
# Processing Record 28 of Set 3 | riverton
# Processing Record 29 of Set 3 | tigil
# Processing Record 30 of Set 3 | tuktoyaktuk
# Processing Record 31 of Set 3 | voronezh
# Processing Record 32 of Set 3 | te anau
# Processing Record 33 of Set 3 | lasa
# Processing Record 34 of Set 3 | muroto
# Processing Record 35 of Set 3 | ust-ilimsk
# Processing Record 36 of Set 3 | khorramshahr
# Processing Record 37 of Set 3 | xuanhua
# Processing Record 38 of Set 3 | shostka
# Processing Record 39 of Set 3 | sisimiut
# Processing Record 40 of Set 3 | ndele
# Processing Record 41 of Set 3 | saint-pierre
# Processing Record 42 of Set 3 | meulaboh
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | provideniya
# Processing Record 45 of Set 3 | husavik
# Processing Record 46 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 3 | cape coast
# Processing Record 48 of Set 3 | houma
# Processing Record 49 of Set 3 | kilindoni
# Processing Record 50 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | lukaya
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | bilma
# Processing Record 5 of Set 4 | atuona
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | gazojak
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | oussouye
# Processing Record 10 of Set 4 | rajauri
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | roald
# Processing Record 13 of Set 4 | kuhestan
# City not found. Skipping...
# Processing Record 14 of Set 4 | mugla
# Processing Record 15 of Set 4 | faya
# Processing Record 16 of Set 4 | po
# City not found. Skipping...
# Processing Record 17 of Set 4 | nampula
# Processing Record 18 of Set 4 | thompson
# Processing Record 19 of Set 4 | mersin
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 4 | belmonte
# Processing Record 23 of Set 4 | hovd
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | honavar
# Processing Record 27 of Set 4 | luanda
# Processing Record 28 of Set 4 | monywa
# Processing Record 29 of Set 4 | lakhdenpokhya
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | liuli
# Processing Record 34 of Set 4 | ziro
# Processing Record 35 of Set 4 | saurimo
# Processing Record 36 of Set 4 | constitucion
# Processing Record 37 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 4 | camargo
# Processing Record 39 of Set 4 | rio grande
# Processing Record 40 of Set 4 | maningrida
# Processing Record 41 of Set 4 | mitchell
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | hue
# Processing Record 44 of Set 4 | arlit
# Processing Record 45 of Set 4 | butaritari
# Processing Record 46 of Set 4 | carutapera
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | gat
# Processing Record 49 of Set 4 | opunake
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | bonthe
# Processing Record 2 of Set 5 | bosaso
# Processing Record 3 of Set 5 | richards bay
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | airai
# Processing Record 6 of Set 5 | mayumba
# Processing Record 7 of Set 5 | kahului
# Processing Record 8 of Set 5 | udachnyy
# Processing Record 9 of Set 5 | mao
# Processing Record 10 of Set 5 | san patricio
# Processing Record 11 of Set 5 | komsomolskiy
# Processing Record 12 of Set 5 | tautira
# Processing Record 13 of Set 5 | voh
# Processing Record 14 of Set 5 | kashi
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | sangar
# Processing Record 17 of Set 5 | tarut
# Processing Record 18 of Set 5 | beringovskiy
# Processing Record 19 of Set 5 | vila velha
# Processing Record 20 of Set 5 | broken hill
# Processing Record 21 of Set 5 | suoyarvi
# Processing Record 22 of Set 5 | port keats
# Processing Record 23 of Set 5 | tateyama
# Processing Record 24 of Set 5 | nador
# Processing Record 25 of Set 5 | izberbash
# Processing Record 26 of Set 5 | marondera
# Processing Record 27 of Set 5 | kavieng
# Processing Record 28 of Set 5 | sao joao da barra
# Processing Record 29 of Set 5 | samarai
# Processing Record 30 of Set 5 | havelock
# Processing Record 31 of Set 5 | zhaotong
# Processing Record 32 of Set 5 | vao
# Processing Record 33 of Set 5 | palma di montechiaro
# Processing Record 34 of Set 5 | monkey bay
# Processing Record 35 of Set 5 | malinovskiy
# Processing Record 36 of Set 5 | tiznit
# Processing Record 37 of Set 5 | asilah
# Processing Record 38 of Set 5 | turukhansk
# Processing Record 39 of Set 5 | san policarpo
# Processing Record 40 of Set 5 | bedesa
# Processing Record 41 of Set 5 | kindu
# Processing Record 42 of Set 5 | kollam
# Processing Record 43 of Set 5 | brora
# Processing Record 44 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 5 | pisco
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | linguere
# Processing Record 49 of Set 5 | arti
# Processing Record 50 of Set 5 | ust-nera
# Processing Record 1 of Set 6 | hilo
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | codrington
# Processing Record 4 of Set 6 | ilhabela
# Processing Record 5 of Set 6 | mackay
# Processing Record 6 of Set 6 | cockburn town
# Processing Record 7 of Set 6 | phichit
# Processing Record 8 of Set 6 | midyat
# Processing Record 9 of Set 6 | verkhnevilyuysk
# Processing Record 10 of Set 6 | at-bashi
# Processing Record 11 of Set 6 | kazachinskoye
# Processing Record 12 of Set 6 | sumbe
# Processing Record 13 of Set 6 | kodiak
# Processing Record 14 of Set 6 | san quintin
# Processing Record 15 of Set 6 | aitape
# Processing Record 16 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | kadoma
# Processing Record 20 of Set 6 | sao francisco
# Processing Record 21 of Set 6 | fairbanks
# Processing Record 22 of Set 6 | buala
# Processing Record 23 of Set 6 | kanchanaburi
# Processing Record 24 of Set 6 | takoradi
# Processing Record 25 of Set 6 | abu samrah
# Processing Record 26 of Set 6 | raichur
# Processing Record 27 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 6 | tura
# Processing Record 29 of Set 6 | belaya gora
# Processing Record 30 of Set 6 | storsteinnes
# Processing Record 31 of Set 6 | djibo
# Processing Record 32 of Set 6 | kaeo
# Processing Record 33 of Set 6 | troitsko-pechorsk
# Processing Record 34 of Set 6 | borovoy
# Processing Record 35 of Set 6 | norman wells
# Processing Record 36 of Set 6 | korla
# Processing Record 37 of Set 6 | quebec
# Processing Record 38 of Set 6 | susanville
# Processing Record 39 of Set 6 | altamont
# Processing Record 40 of Set 6 | esso
# Processing Record 41 of Set 6 | souillac
# Processing Record 42 of Set 6 | syriam
# Processing Record 43 of Set 6 | alexandria
# Processing Record 44 of Set 6 | banda aceh
# Processing Record 45 of Set 6 | saint anthony
# Processing Record 46 of Set 6 | weiser
# Processing Record 47 of Set 6 | jutai
# Processing Record 48 of Set 6 | noumea
# Processing Record 49 of Set 6 | visnes
# Processing Record 50 of Set 6 | enshi
# Processing Record 1 of Set 7 | klyuchi
# Processing Record 2 of Set 7 | san carlos de bariloche
# Processing Record 3 of Set 7 | taltal
# Processing Record 4 of Set 7 | shieli
# Processing Record 5 of Set 7 | andreapol
# Processing Record 6 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 7 | puerto ayora
# Processing Record 8 of Set 7 | saint-augustin
# Processing Record 9 of Set 7 | pasighat
# Processing Record 10 of Set 7 | svetlyy
# Processing Record 11 of Set 7 | jiblah
# Processing Record 12 of Set 7 | vila franca do campo
# Processing Record 13 of Set 7 | ube
# Processing Record 14 of Set 7 | penukonda
# Processing Record 15 of Set 7 | fortuna
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 7 | launceston
# Processing Record 19 of Set 7 | ahipara
# Processing Record 20 of Set 7 | deep river
# Processing Record 21 of Set 7 | ngudu
# Processing Record 22 of Set 7 | necochea
# Processing Record 23 of Set 7 | oranjemund
# Processing Record 24 of Set 7 | yeppoon
# Processing Record 25 of Set 7 | mirabad
# Processing Record 26 of Set 7 | chuy
# Processing Record 27 of Set 7 | pokanayevka
# City not found. Skipping...
# Processing Record 28 of Set 7 | arona
# Processing Record 29 of Set 7 | denpasar
# Processing Record 30 of Set 7 | dalby
# Processing Record 31 of Set 7 | baltasi
# Processing Record 32 of Set 7 | buenos aires
# Processing Record 33 of Set 7 | diego de almagro
# Processing Record 34 of Set 7 | olafsvik
# Processing Record 35 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 7 | muros
# Processing Record 37 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 7 | severo-kurilsk
# Processing Record 39 of Set 7 | seabra
# Processing Record 40 of Set 7 | lorengau
# Processing Record 41 of Set 7 | takhtamygda
# Processing Record 42 of Set 7 | kemijarvi
# Processing Record 43 of Set 7 | tam ky
# Processing Record 44 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | sadovoye
# Processing Record 46 of Set 7 | waingapu
# Processing Record 47 of Set 7 | zhigansk
# Processing Record 48 of Set 7 | pacasmayo
# Processing Record 49 of Set 7 | lanigan
# Processing Record 50 of Set 7 | durban
# Processing Record 1 of Set 8 | dharchula
# Processing Record 2 of Set 8 | rawlins
# Processing Record 3 of Set 8 | sur
# Processing Record 4 of Set 8 | peniche
# Processing Record 5 of Set 8 | margate
# Processing Record 6 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sioux lookout
# Processing Record 8 of Set 8 | batagay-alyta
# Processing Record 9 of Set 8 | usinsk
# Processing Record 10 of Set 8 | narsaq
# Processing Record 11 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 12 of Set 8 | nhulunbuy
# Processing Record 13 of Set 8 | aban
# Processing Record 14 of Set 8 | raudeberg
# Processing Record 15 of Set 8 | anchorage
# Processing Record 16 of Set 8 | muli
# Processing Record 17 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 8 | guaraniacu
# Processing Record 19 of Set 8 | honiara
# Processing Record 20 of Set 8 | moranbah
# Processing Record 21 of Set 8 | mount isa
# Processing Record 22 of Set 8 | cabo san lucas
# Processing Record 23 of Set 8 | taoudenni
# Processing Record 24 of Set 8 | lokosovo
# Processing Record 25 of Set 8 | kresna
# Processing Record 26 of Set 8 | tahlequah
# Processing Record 27 of Set 8 | vestmannaeyjar
# Processing Record 28 of Set 8 | canandaigua
# Processing Record 29 of Set 8 | simao
# Processing Record 30 of Set 8 | huarmey
# Processing Record 31 of Set 8 | gweru
# Processing Record 32 of Set 8 | buraydah
# Processing Record 33 of Set 8 | alta gracia
# Processing Record 34 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 8 | olinda
# Processing Record 36 of Set 8 | okhotsk
# Processing Record 37 of Set 8 | naryan-mar
# Processing Record 38 of Set 8 | hamilton
# Processing Record 39 of Set 8 | kota belud
# Processing Record 40 of Set 8 | coihaique
# Processing Record 41 of Set 8 | vanavara
# Processing Record 42 of Set 8 | ginda
# Processing Record 43 of Set 8 | bambous virieux
# Processing Record 44 of Set 8 | katsina
# Processing Record 45 of Set 8 | yumen
# Processing Record 46 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 8 | conceicao do araguaia
# Processing Record 48 of Set 8 | hambantota
# Processing Record 49 of Set 8 | lerwick
# Processing Record 50 of Set 8 | cobija
# Processing Record 1 of Set 9 | tunghsiao
# City not found. Skipping...
# Processing Record 2 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 9 | rovaniemi
# Processing Record 4 of Set 9 | ust-kulom
# Processing Record 5 of Set 9 | college
# Processing Record 6 of Set 9 | las vegas
# Processing Record 7 of Set 9 | manuk mangkaw
# Processing Record 8 of Set 9 | slave lake
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | quelimane
# Processing Record 11 of Set 9 | chase
# Processing Record 12 of Set 9 | viedma
# Processing Record 13 of Set 9 | piacabucu
# Processing Record 14 of Set 9 | rychvald
# Processing Record 15 of Set 9 | yinchuan
# Processing Record 16 of Set 9 | kiama
# Processing Record 17 of Set 9 | hobyo
# Processing Record 18 of Set 9 | ca mau
# Processing Record 19 of Set 9 | zangakatun
# Processing Record 20 of Set 9 | atasu
# Processing Record 21 of Set 9 | ketchikan
# Processing Record 22 of Set 9 | mitsamiouli
# Processing Record 23 of Set 9 | north battleford
# Processing Record 24 of Set 9 | tuatapere
# Processing Record 25 of Set 9 | itupiranga
# Processing Record 26 of Set 9 | abu kamal
# Processing Record 27 of Set 9 | padang
# Processing Record 28 of Set 9 | inongo
# Processing Record 29 of Set 9 | helong
# Processing Record 30 of Set 9 | harper
# Processing Record 31 of Set 9 | mandalgovi
# Processing Record 32 of Set 9 | marsa matruh
# Processing Record 33 of Set 9 | gazanjyk
# Processing Record 34 of Set 9 | georgiyevskoye
# Processing Record 35 of Set 9 | ukholovo
# Processing Record 36 of Set 9 | paoua
# Processing Record 37 of Set 9 | mazamari
# Processing Record 38 of Set 9 | garowe
# Processing Record 39 of Set 9 | tabuk
# Processing Record 40 of Set 9 | acapulco
# Processing Record 41 of Set 9 | gharghoda
# Processing Record 42 of Set 9 | el balyana
# City not found. Skipping...
# Processing Record 43 of Set 9 | rumford
# Processing Record 44 of Set 9 | lahaina
# Processing Record 45 of Set 9 | praia
# Processing Record 46 of Set 9 | ajdabiya
# Processing Record 47 of Set 9 | santa maria
# Processing Record 48 of Set 9 | requena
# Processing Record 49 of Set 9 | coxim
# Processing Record 50 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 1 of Set 10 | cayenne
# Processing Record 2 of Set 10 | sistranda
# Processing Record 3 of Set 10 | envira
# Processing Record 4 of Set 10 | yar-sale
# Processing Record 5 of Set 10 | caxito
# Processing Record 6 of Set 10 | penzance
# Processing Record 7 of Set 10 | eureka
# Processing Record 8 of Set 10 | ribeira grande
# Processing Record 9 of Set 10 | namibe
# Processing Record 10 of Set 10 | yacuiba
# Processing Record 11 of Set 10 | warrington
# Processing Record 12 of Set 10 | atar
# Processing Record 13 of Set 10 | mokhsogollokh
# Processing Record 14 of Set 10 | sechura
# Processing Record 15 of Set 10 | nisia floresta
# Processing Record 16 of Set 10 | maracaibo
# Processing Record 17 of Set 10 | baglung
# Processing Record 18 of Set 10 | plettenberg bay
# Processing Record 19 of Set 10 | dunedin
# Processing Record 20 of Set 10 | nyurba
# Processing Record 21 of Set 10 | santa monica
# Processing Record 22 of Set 10 | general roca
# Processing Record 23 of Set 10 | bam
# Processing Record 24 of Set 10 | saint-leu
# Processing Record 25 of Set 10 | trinidad
# Processing Record 26 of Set 10 | qax
# Processing Record 27 of Set 10 | aswan
# Processing Record 28 of Set 10 | mogadishu
# Processing Record 29 of Set 10 | bellview
# Processing Record 30 of Set 10 | nevel
# Processing Record 31 of Set 10 | kavaratti
# Processing Record 32 of Set 10 | mahmudabad
# Processing Record 33 of Set 10 | carupano
# Processing Record 34 of Set 10 | axim
# Processing Record 35 of Set 10 | ilulissat
# Processing Record 36 of Set 10 | xuddur
# Processing Record 37 of Set 10 | bathsheba
# Processing Record 38 of Set 10 | dawei
# Processing Record 39 of Set 10 | maniitsoq
# Processing Record 40 of Set 10 | langsa
# Processing Record 41 of Set 10 | alekseyevka
# Processing Record 42 of Set 10 | beyneu
# Processing Record 43 of Set 10 | yevlax
# Processing Record 44 of Set 10 | baoding
# Processing Record 45 of Set 10 | kjopsvik
# Processing Record 46 of Set 10 | aukra
# Processing Record 47 of Set 10 | grindavik
# Processing Record 48 of Set 10 | cherskiy
# Processing Record 49 of Set 10 | gornyy
# Processing Record 50 of Set 10 | djougou
# Processing Record 1 of Set 11 | kidal
# Processing Record 2 of Set 11 | devrek
# Processing Record 3 of Set 11 | afua
# Processing Record 4 of Set 11 | san pedro
# Processing Record 5 of Set 11 | puerto escondido
# Processing Record 6 of Set 11 | kamaishi
# Processing Record 7 of Set 11 | sarangani
# Processing Record 8 of Set 11 | parrita
# Processing Record 9 of Set 11 | srednekolymsk
# Processing Record 10 of Set 11 | iquique
# Processing Record 11 of Set 11 | natitingou
# Processing Record 12 of Set 11 | teguldet
# Processing Record 13 of Set 11 | port hedland
# Processing Record 14 of Set 11 | baykit
# Processing Record 15 of Set 11 | nome
# Processing Record 16 of Set 11 | kruisfontein
# Processing Record 17 of Set 11 | lumeje
# Processing Record 18 of Set 11 | panama city
# Processing Record 19 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 11 | port blair
# Processing Record 22 of Set 11 | miraflores
# Processing Record 23 of Set 11 | mizan teferi
# Processing Record 24 of Set 11 | malanville
# Processing Record 25 of Set 11 | vaitape
# Processing Record 26 of Set 11 | cody
# Processing Record 27 of Set 11 | pyapon
# Processing Record 28 of Set 11 | konstantinovskiy
# Processing Record 29 of Set 11 | port macquarie
# Processing Record 30 of Set 11 | poplar bluff
# Processing Record 31 of Set 11 | bolshaya dzhalga
# Processing Record 32 of Set 11 | westport
# Processing Record 33 of Set 11 | gualaquiza
# Processing Record 34 of Set 11 | fortuna foothills
# Processing Record 35 of Set 11 | siyabuswa
# Processing Record 36 of Set 11 | kalianget
# Processing Record 37 of Set 11 | togur
# Processing Record 38 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 11 | namatanai
# Processing Record 40 of Set 11 | charagua
# Processing Record 41 of Set 11 | agirish
# Processing Record 42 of Set 11 | totness
# Processing Record 43 of Set 11 | south hadley
# Processing Record 44 of Set 11 | cairns
# Processing Record 45 of Set 11 | kulhudhuffushi
# Processing Record 46 of Set 11 | road town
# Processing Record 47 of Set 11 | bilibino
# Processing Record 48 of Set 11 | kunming
# Processing Record 49 of Set 11 | merauke
# Processing Record 50 of Set 11 | the valley
# Processing Record 1 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 12 | polunochnoye
# Processing Record 3 of Set 12 | manzanillo
# Processing Record 4 of Set 12 | rafai
# Processing Record 5 of Set 12 | blagoyevo
# Processing Record 6 of Set 12 | carrollton
# Processing Record 7 of Set 12 | ngorongoro
# Processing Record 8 of Set 12 | verkhovazhye
# Processing Record 9 of Set 12 | paramonga
# Processing Record 10 of Set 12 | paracuru
# Processing Record 11 of Set 12 | dingle
# Processing Record 12 of Set 12 | ladario
# Processing Record 13 of Set 12 | bengkulu
# Processing Record 14 of Set 12 | kyakhta
# Processing Record 15 of Set 12 | litovko
# Processing Record 16 of Set 12 | panguna
# Processing Record 17 of Set 12 | mwingi
# Processing Record 18 of Set 12 | limoeiro do ajuru
# Processing Record 19 of Set 12 | berdigestyakh
# Processing Record 20 of Set 12 | el alto
# Processing Record 21 of Set 12 | broome
# Processing Record 22 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 12 | kimberley
# Processing Record 24 of Set 12 | ostrovnoy
# Processing Record 25 of Set 12 | mbanza-ngungu
# Processing Record 26 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 12 | ukiah
# Processing Record 28 of Set 12 | meylan
# Processing Record 29 of Set 12 | yarmouth
# Processing Record 30 of Set 12 | el badari
# City not found. Skipping...
# Processing Record 31 of Set 12 | half moon bay
# Processing Record 32 of Set 12 | salinas
# Processing Record 33 of Set 12 | makat
# Processing Record 34 of Set 12 | kalmunai
# Processing Record 35 of Set 12 | itoman
# Processing Record 36 of Set 12 | durango
# Processing Record 37 of Set 12 | tucuman
# Processing Record 38 of Set 12 | wilmington
# Processing Record 39 of Set 12 | tonj
# Processing Record 40 of Set 12 | agadez
# Processing Record 41 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 12 | aykhal
# Processing Record 43 of Set 12 | sibolga
# Processing Record 44 of Set 12 | riyadh
# Processing Record 45 of Set 12 | bursa
# Processing Record 46 of Set 12 | tungor
# Processing Record 47 of Set 12 | chara
# Processing Record 48 of Set 12 | imbituba
# Processing Record 49 of Set 12 | kinshasa
# Processing Record 50 of Set 12 | mareeba
# Processing Record 1 of Set 13 | fukue
# Processing Record 2 of Set 13 | ratnapura
# Processing Record 3 of Set 13 | san andres
# Processing Record 4 of Set 13 | diamantina
# Processing Record 5 of Set 13 | safford
# Processing Record 6 of Set 13 | pandan
# Processing Record 7 of Set 13 | adrar
# Processing Record 8 of Set 13 | athabasca
# Processing Record 9 of Set 13 | paita
# Processing Record 10 of Set 13 | maceio
# Processing Record 11 of Set 13 | along
# Processing Record 12 of Set 13 | dakar
# Processing Record 13 of Set 13 | sarandi
# Processing Record 14 of Set 13 | makakilo city
# Processing Record 15 of Set 13 | frumusita
# Processing Record 16 of Set 13 | santa cruz
# Processing Record 17 of Set 13 | prince rupert
# Processing Record 18 of Set 13 | burnie
# Processing Record 19 of Set 13 | inhambane
# Processing Record 20 of Set 13 | honningsvag
# Processing Record 21 of Set 13 | gzhatsk
# City not found. Skipping...
# Processing Record 22 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 23 of Set 13 | tongren
# Processing Record 24 of Set 13 | berezovka
# Processing Record 25 of Set 13 | sabang
# Processing Record 26 of Set 13 | vostok
# Processing Record 27 of Set 13 | barranca
# Processing Record 28 of Set 13 | iquitos
# Processing Record 29 of Set 13 | gilleleje
# Processing Record 30 of Set 13 | igarka
# Processing Record 31 of Set 13 | inta
# Processing Record 32 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 13 | yekaterinoslavka
# Processing Record 34 of Set 13 | nishihara
# Processing Record 35 of Set 13 | evensk
# Processing Record 36 of Set 13 | ambarawa
# Processing Record 37 of Set 13 | chhoti sadri
# Processing Record 38 of Set 13 | kloulklubed
# Processing Record 39 of Set 13 | pacific grove
# Processing Record 40 of Set 13 | muravlenko
# Processing Record 41 of Set 13 | boshnyakovo
# Processing Record 42 of Set 13 | mormugao
# Processing Record 43 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 13 | edd
# Processing Record 45 of Set 13 | aranda de duero
# Processing Record 46 of Set 13 | pau brasil
# Processing Record 47 of Set 13 | tiarei
# Processing Record 48 of Set 13 | akyab
# Processing Record 49 of Set 13 | herat
# Processing Record 50 of Set 13 | rio gallegos
# Processing Record 1 of Set 14 | weston
# Processing Record 2 of Set 14 | lakatoro
# Processing Record 3 of Set 14 | seoul
# Processing Record 4 of Set 14 | kankaanpaa
# Processing Record 5 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 14 | benavente
# Processing Record 7 of Set 14 | kununurra
# Processing Record 8 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 14 | neftegorsk
# Processing Record 10 of Set 14 | donskoye
# Processing Record 11 of Set 14 | rosetta
# Processing Record 12 of Set 14 | mitzic
# Processing Record 13 of Set 14 | bukama
# Processing Record 14 of Set 14 | jalu
# Processing Record 15 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | humaita
# Processing Record 17 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 18 of Set 14 | subaytilah
# City not found. Skipping...
# Processing Record 19 of Set 14 | timra
# Processing Record 20 of Set 14 | baghdad
# Processing Record 21 of Set 14 | barstow
# Processing Record 22 of Set 14 | bonfim
# Processing Record 23 of Set 14 | tutoia
# Processing Record 24 of Set 14 | pemangkat
# Processing Record 25 of Set 14 | mikumi
# Processing Record 26 of Set 14 | gusau
# Processing Record 27 of Set 14 | hit
# Processing Record 28 of Set 14 | sungaipenuh
# Processing Record 29 of Set 14 | svobodnyy
# Processing Record 30 of Set 14 | sulphur
# Processing Record 31 of Set 14 | iracoubo
# Processing Record 32 of Set 14 | bandarbeyla
# Processing Record 33 of Set 14 | koslan
# Processing Record 34 of Set 14 | mandal
# Processing Record 35 of Set 14 | fram
# Processing Record 36 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 14 | sept-iles
# Processing Record 38 of Set 14 | batsfjord
# Processing Record 39 of Set 14 | daru
# Processing Record 40 of Set 14 | porto novo
# Processing Record 41 of Set 14 | dunn
# Processing Record 42 of Set 14 | high level
# Processing Record 43 of Set 14 | burila mare
# Processing Record 44 of Set 14 | tuy hoa
# Processing Record 45 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 14 | salekhard
# Processing Record 47 of Set 14 | sorland
# Processing Record 48 of Set 14 | tebingtinggi
# Processing Record 49 of Set 14 | bagado
# Processing Record 50 of Set 14 | port augusta
# Processing Record 1 of Set 15 | gandia
# Processing Record 2 of Set 15 | jos
# Processing Record 3 of Set 15 | north bend
# Processing Record 4 of Set 15 | tayshet
# Processing Record 5 of Set 15 | saint-joseph
# Processing Record 6 of Set 15 | clarence town
# Processing Record 7 of Set 15 | sakakah
# Processing Record 8 of Set 15 | algiers
# Processing Record 9 of Set 15 | saint-jean-port-joli
# Processing Record 10 of Set 15 | mikhaylovka
# Processing Record 11 of Set 15 | puerto madero
# Processing Record 12 of Set 15 | kimbe
# Processing Record 13 of Set 15 | hirado
# Processing Record 14 of Set 15 | tahoua
# Processing Record 15 of Set 15 | solnechnyy
# Processing Record 16 of Set 15 | ixtapa
# Processing Record 17 of Set 15 | hay river
# Processing Record 18 of Set 15 | waipawa
# Processing Record 19 of Set 15 | agen
# Processing Record 20 of Set 15 | zilair
# Processing Record 21 of Set 15 | berlevag
# Processing Record 22 of Set 15 | dukat
# Processing Record 23 of Set 15 | nemuro
# Processing Record 24 of Set 15 | raga
# Processing Record 25 of Set 15 | constantine
# Processing Record 26 of Set 15 | canico
# Processing Record 27 of Set 15 | akureyri
# Processing Record 28 of Set 15 | sambava
# Processing Record 29 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 15 | ugoofaaru
# Processing Record 31 of Set 15 | darbhanga
# Processing Record 32 of Set 15 | puerto penasco
# Processing Record 33 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 34 of Set 15 | shasta lake
# Processing Record 35 of Set 15 | ambanja
# Processing Record 36 of Set 15 | los llanos de aridane
# Processing Record 37 of Set 15 | amravati
# Processing Record 38 of Set 15 | derzhavinsk
# Processing Record 39 of Set 15 | san javier
# Processing Record 40 of Set 15 | christchurch
# Processing Record 41 of Set 15 | luganville
# Processing Record 42 of Set 15 | antsohihy
# Processing Record 43 of Set 15 | molchanovo
# Processing Record 44 of Set 15 | powell
# Processing Record 45 of Set 15 | mandera
# Processing Record 46 of Set 15 | male
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Jamestown  42.0970  -79.2353     55.02        93         100
# 1          Mataura -46.1927  168.8643     63.48        55          26
# 2       Kosh-Agach  50.0000   88.6667     46.22        34         100
# 3            Bluff -46.6000  168.3333     63.81        74          34
# 4           Durham  36.0335  -78.8664     66.29        91         100
# 5           Barrow  71.2906 -156.7887     19.42        86         100
# 6           Avarua -21.2078 -159.7750     84.25        74          75
# 7  Sulphur Springs  33.1385  -95.6011     78.51        47           0
# 8            Vaini -21.2000 -175.2000     82.56        83          75
# 9           Nabire  -3.3667  135.4833     82.90        77         100
#
#    Wind Speed Country Current Description                 Date
# 0       13.80      US     overcast clouds  2022-05-02 00:36:00
# 1        5.37      NZ    scattered clouds  2022-05-02 00:39:46
# 2        3.24      RU     overcast clouds  2022-05-02 00:39:46
# 3       11.77      NZ    scattered clouds  2022-05-02 00:39:47
# 4        1.99      US     overcast clouds  2022-05-02 00:38:50
# 5       14.97      US     overcast clouds  2022-05-02 00:35:03
# 6        5.75      CK       broken clouds  2022-05-02 00:39:47
# 7        5.75      US           clear sky  2022-05-02 00:39:48
# 8       14.97      TO       broken clouds  2022-05-02 00:39:48
# 9        2.15      ID     overcast clouds  2022-05-02 00:39:49

# %%
# Reorder the columns in the order you want the to appear.
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
# Assign city data df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown      US  42.0970  -79.2353     55.02        93         100
# 1       Mataura      NZ -46.1927  168.8643     63.48        55          26
# 2    Kosh-Agach      RU  50.0000   88.6667     46.22        34         100
# 3         Bluff      NZ -46.6000  168.3333     63.81        74          34
# 4        Durham      US  36.0335  -78.8664     66.29        91         100
# ..          ...     ...      ...       ...       ...       ...         ...
# 679   Antsohihy      MG -14.8796   47.9875     73.29        96          26
# 680  Molchanovo      RU  57.5817   83.7692     37.27        79         100
# 681      Powell      US  40.1578  -83.0752     64.40        66          39
# 682     Mandera      KE   3.9366   41.8670     75.61        79         100
# 683        Male      MV   4.1748   73.5089     85.95        74          75
#
#      Wind Speed Current Description
# 0         13.80     overcast clouds
# 1          5.37    scattered clouds
# 2          3.24     overcast clouds
# 3         11.77    scattered clouds
# 4          1.99     overcast clouds
# ..          ...                 ...
# 679        1.88    scattered clouds
# 680        5.84     overcast clouds
# 681        5.01    scattered clouds
# 682        9.71     overcast clouds
# 683       20.71       broken clouds
#
# [684 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/.dataset/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
import os
city_data_df.to_csv(r'C:\path\to\Weather_Database\WeatherPy_Database.csv', index_label="City_ID")
